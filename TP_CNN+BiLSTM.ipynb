# %% [markdown]
# <a href="https://colab.research.google.com/github/AArna1211/Traffic-prediction/blob/main/TP_CNN%2BBiLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_absolute_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Bidirectional, LSTM, Flatten, Dense, Dropout, TimeDistributed, RepeatVector
from tensorflow.keras.callbacks import EarlyStopping

# %%
data = pd.read_csv("/content/Traffic.csv")

# %%
# Encode categorical "Traffic Situation"
label_encoder = LabelEncoder()
data["Traffic Situation Encoded"] = label_encoder.fit_transform(data["Traffic Situation"])

# Prepare features and labels
X = data[["CarCount", "BikeCount", "BusCount", "TruckCount", "Total"]].values
y = data["Traffic Situation Encoded"].values

# %%
# Reshape input for time-series forecasting (sequence length = 3 for long-term prediction)
sequence_length = 3
X_sequences = []
y_sequences = []
for i in range(len(X) - sequence_length):
    X_sequences.append(X[i:i + sequence_length])
    y_sequences.append(y[i + sequence_length])
X_sequences = np.array(X_sequences)
y_sequences = np.array(y_sequences)

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_sequences, y_sequences, test_size=0.2, random_state=42)

# %%
# Define CNN-Bidirectional LSTM model for long-term forecasting
model = Sequential([
    TimeDistributed(Conv1D(filters=64, kernel_size=2, activation='relu'), input_shape=(sequence_length, X.shape[1], 1)),
    TimeDistributed(Flatten()),
    Bidirectional(LSTM(64, activation='relu', return_sequences=True)),
    Bidirectional(LSTM(32, activation='relu')),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(len(label_encoder.classes_), activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Implement Early Stopping
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

# %%
# Train model
history = model.fit(X_train, y_train, epochs=50, batch_size=2, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.6233 - loss: 1.0931 - val_accuracy: 0.7345 - val_loss: 0.9294
# Epoch 2/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7275 - loss: 0.8299 - val_accuracy: 0.7277 - val_loss: 0.7929
# Epoch 3/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6869 - loss: 0.8951 - val_accuracy: 0.7042 - val_loss: 0.7917
# Epoch 4/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7173 - loss: 0.8059 - val_accuracy: 0.7361 - val_loss: 0.7511
# Epoch 5/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7439 - loss: 0.7473 - val_accuracy: 0.7529 - val_loss: 0.6903
# Epoch 6/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.7377 - loss: 0.7723 - val_accuracy: 0.7143 - val_loss: 0.7251
# Epoch 7/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7174 - loss: 0.7820 - val_accuracy: 0.7563 - val_loss: 0.6945
# Epoch 8/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.7435 - loss: 0.8142 - val_accuracy: 0.7445 - val_loss: 0.7239
# Epoch 9/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.7250 - loss: 0.7491 - val_accuracy: 0.7479 - val_loss: 0.6976
# Epoch 10/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.7146 - loss: 0.7626 - val_accuracy: 0.7580 - val_loss: 0.7245
# Epoch 11/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.7297 - loss: 0.7401 - val_accuracy: 0.7546 - val_loss: 0.6911
# Epoch 12/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.7201 - loss: 0.7643 - val_accuracy: 0.7496 - val_loss: 0.6803
# Epoch 13/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.7330 - loss: 0.7518 - val_accuracy: 0.7513 - val_loss: 0.6828
# Epoch 14/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.7237 - loss: 0.7445 - val_accuracy: 0.7479 - val_loss: 0.6917
# Epoch 15/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.7299 - loss: 0.7370 - val_accuracy: 0.7630 - val_loss: 0.6768
# Epoch 16/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7265 - loss: 0.7542 - val_accuracy: 0.7311 - val_loss: 0.7336
# Epoch 17/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7252 - loss: 0.7806 - val_accuracy: 0.7429 - val_loss: 0.6898
# Epoch 18/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.7245 - loss: 0.7337 - val_accuracy: 0.7513 - val_loss: 0.7081
# Epoch 19/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7478 - loss: 0.7101 - val_accuracy: 0.7513 - val_loss: 0.6747
# Epoch 20/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.7367 - loss: 0.7294 - val_accuracy: 0.7496 - val_loss: 0.6743
# Epoch 21/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.7434 - loss: 0.7305 - val_accuracy: 0.7328 - val_loss: 0.7225
# Epoch 22/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.7297 - loss: 0.7385 - val_accuracy: 0.7462 - val_loss: 0.7376
# Epoch 23/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7317 - loss: 0.7411 - val_accuracy: 0.7563 - val_loss: 0.6975
# Epoch 24/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7352 - loss: 0.7105 - val_accuracy: 0.7681 - val_loss: 0.6829
# Epoch 25/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7429 - loss: 0.7062 - val_accuracy: 0.7546 - val_loss: 0.6954
# Epoch 26/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7518 - loss: 0.6920 - val_accuracy: 0.7261 - val_loss: 0.7812
# Epoch 27/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7282 - loss: 0.7392 - val_accuracy: 0.7563 - val_loss: 0.6885
# Epoch 28/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.7374 - loss: 0.6903 - val_accuracy: 0.7630 - val_loss: 0.6872
# Epoch 29/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7177 - loss: 0.7261 - val_accuracy: 0.7529 - val_loss: 0.7586
# Epoch 30/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.7198 - loss: 0.7280 - val_accuracy: 0.7580 - val_loss: 0.7051
# Epoch 31/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7309 - loss: 0.7099 - val_accuracy: 0.7664 - val_loss: 0.6954
# Epoch 32/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7387 - loss: 0.7366 - val_accuracy: 0.7529 - val_loss: 0.6935
# Epoch 33/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7293 - loss: 0.7211 - val_accuracy: 0.7345 - val_loss: 0.7485
# Epoch 34/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.7290 - loss: 0.7512 - val_accuracy: 0.7445 - val_loss: 0.7447
# Epoch 35/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.7390 - loss: 0.6858 - val_accuracy: 0.7546 - val_loss: 0.7375
# Epoch 36/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.7326 - loss: 0.7229 - val_accuracy: 0.7529 - val_loss: 0.6875
# Epoch 37/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7258 - loss: 0.7174 - val_accuracy: 0.7613 - val_loss: 0.6983
# Epoch 38/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7438 - loss: 0.6948 - val_accuracy: 0.7496 - val_loss: 0.7325
# Epoch 39/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7429 - loss: 0.7032 - val_accuracy: 0.7597 - val_loss: 0.7305
# Epoch 40/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7191 - loss: 0.7144 - val_accuracy: 0.7529 - val_loss: 0.7351
# Epoch 41/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.7512 - loss: 0.6706 - val_accuracy: 0.7361 - val_loss: 0.7573
# Epoch 42/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7623 - loss: 0.6735 - val_accuracy: 0.7580 - val_loss: 0.6925
# Epoch 43/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7433 - loss: 0.7622 - val_accuracy: 0.7546 - val_loss: 0.7262
# Epoch 44/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7423 - loss: 0.6851 - val_accuracy: 0.7529 - val_loss: 0.7303
# Epoch 45/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.7654 - loss: 0.6308 - val_accuracy: 0.7513 - val_loss: 0.8023
# Epoch 46/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7484 - loss: 0.6809 - val_accuracy: 0.7563 - val_loss: 0.7214
# Epoch 47/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7450 - loss: 0.6684 - val_accuracy: 0.7630 - val_loss: 0.9032
# Epoch 48/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7539 - loss: 0.6818 - val_accuracy: 0.7546 - val_loss: 0.9461
# Epoch 49/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7479 - loss: 0.6655 - val_accuracy: 0.7580 - val_loss: 0.7606
# Epoch 50/50
# 1189/1189 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7557 - loss: 0.6483 - val_accuracy: 0.7563 - val_loss: 0.7742

# %%
# Evaluate model
y_pred = np.argmax(model.predict(X_test), axis=1)
accuracy = accuracy_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Mean Absolute Error: {mae:.4f}")

# Plot training history
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step
# Test Accuracy: 0.7563
# Mean Absolute Error: 0.4303
